# %% [markdown]
# #### Project Milestones

# %% [markdown]
# $Mar. 15$

# %% [markdown]
# | Deliverable  | Percent Complete    | Estimated Completion  Date  | Percent Completed by Next Milestone|
# |:-------------|:-----------|:------|:------|
# | Code | 5%  | Apr. 12      | 20%   |
# | Paper | 3%  | Apr. 19   | 10%   |
# | Demo | 0%  | Apr. 20   | 0%   |
# | Presentation | 0%  |  Apr. 25   | 0%   |

# %% [markdown]
# 1\. With this being our first milestone, we have been working on completing the project proposal and finding a
#    suitable speech command dataset.

# %% [markdown]
# 2\. Our team has yet complete the pre-processing of our dataset.

# %% [markdown]
# 3\. Before the next milestone, we need to complete the pre-processing, and create our input dataset by using audio
#     samples of each object generated by each team member to allow for variations of tone, accent, etc. and a reasonable
#     number of samples altogether.
#
# Team Member Roles:<br>
# Austin: Record audio samples of each object , Research neural net architecture<br>
# Fadlullah: Record audio samples of each object , Pre-Processing of data set<br>
# Joshua: Record audio samples of each object , Research neural net architecture<br>
# Mena: Record audio samples of each object , Write first milestone<br>
# Mohamed: Record audio samples of each object , Write the Introduction for the paper<br>

# %% [markdown]
# $Mar. 22$

# %% [markdown]
# | Deliverable  | Percent Complete    | Estimated Completion  Date  | Percent Completed by Next Milestone|
# |:-------------|:-----------|:------|:------|
# | Code | 10%  | Apr. 12      | 20%   |
# | Paper | 7%  | Apr. 19   | 15%   |
# | Demo | 0%  | Apr. 20   | 0%   |
# | Presentation | 0%  |  Apr. 25   | 0%   |

# %% [markdown]
# 1\. We have completed finding a suitable dataset of speech commands. We decided that the best method would be to create our own dataset. Each member was able to record samples. Altogether we have several hundred samples of different objects with different speakers, tones, and accents to allow for variation.

# %% [markdown]
# 2\. Our team has yet to complete the pre-processing of the dataset although progress has been made from the previous week.

# %% [markdown]
# 3\. Before the next milestone, we would like to have the pre-processing completed. In addition, we need more recording samples to expand our dataset.
#
#    Team Member Roles: <br>
#    Austin: Record more samples , Research neural net architecture<br>
#    Fadlullah: Record more samples , Pre-Processing of data set<br>
#    Joshua: Record more samples , Research neural net architecture<br>
#    Mena: Record more samples , Write second milestone<br>
#    Mohamed: Record more samples , Write the Introduction for the paper<br>

# %% [markdown]
# $Mar. 29$

# %% [markdown]
# | Deliverable  | Percent Complete    | Estimated Completion  Date  | Percent Completed by Next Milestone|
# |:-------------|:-----------|:------|:------|
# | Code | 20%  | Apr. 12      | 30%   |
# | Paper | 12%  | Apr. 19   | 17%   |
# | Demo | 0%  | Apr. 20   | 0%   |
# | Presentation | 0%  |  Apr. 25   | 0%   |

# %% [markdown]
# 1\. We have gathererd the recording samples that we need and have completed the pre-processing of the data. We have also researched the network archetecture that will be used. The introduction for the paper is complete.

# %% [markdown]
# 2\. All deliverable goals from the previous week have been completed. The introduction needs to be committed to GitHub.

# %% [markdown]
# 3\. Before the next milestone, we would like to make some notable progress on the code, including preparing the convolutional network. We want to begin writing the methods and research how we will use the arduino.
#
#    Team Member Roles: <br>
#    Austin: Work on code, work on convolutional network code<br>
#    Fadlullah: Work on code , look into methods for the paper<br>
#    Joshua: Begin researching and writing methods section of the paper<br>
#    Mena: Research Arduino , Write milestone<br>
#    Mohamed: Work on convolutional network code, commit introduction to GitHub<br>

# %% [markdown]
# $Apr. 05$

# %% [markdown]
# | Deliverable  | Percent Complete    | Estimated Completion  Date  | Percent Completed by Next Milestone|
# |:-------------|:-----------|:------|:------|
# | Code | 30%  | Apr. 12      | 50%   |
# | Paper | 17%  | Apr. 19   | 25%   |
# | Demo | 0%  | Apr. 20   | 0%   |
# | Presentation | 0%  |  Apr. 25   | 0%   |

# %% [markdown]
# 1\. We have made notable progress on the the network code and on researching the methodology.

# %% [markdown]
# 2\. We have yet to finish writing the methods section of the paper. The network code needs more work.

# %% [markdown]
# 3\. Before the next milestone, we would like to come near a finish line with the network and begin on the next section of the code. We need to finish writing the methods and begin looking at the model.
#
#    Team Member Roles: <br>
#    Austin: Work on code- neural network code<br>
#    Fadlullah: Work on Arduino and Raspberry Pi code<br>
#    Joshua: Write the methods<br>
#    Mena: Research Arduino, begin running model and tuning parameters<br>
#    Mohamed: Work on network code<br>

# %% [markdown]
# $Apr. 12$

# %% [markdown]
# | Deliverable  | Percent Complete    | Estimated Completion  Date  | Percent Completed by Next Milestone|
# |:-------------|:-----------|:------|:------|
# | Code | 50%  | Apr. 26      | 75%   |
# | Paper | 25%  | Apr. 21   | 75%   |
# | Demo | 10%  | Apr. 20   | 50%   |
# | Presentation | 0%  |  Apr. 25   | 0%   |

# %% [markdown]
# 1\. We have made significant progress on the the network code, working on the model, and researching the methodology including the configuration of the devices with the code and the neural network.

# %% [markdown]
# 2\. The code is near completion but needs more work. We have yet to complete the methods section of the paper.

# %% [markdown]
# 3\. Before the next milestone, we would like to come near a finish line with the entire code and have the network complete. The methods need to be finalized and progress needs to be made on the results and conclusion sections of the paper. We need to begin working on the demo.
#
#    Team Member Roles: <br>
#    Austin: Write and finalize methods<br>
#    Fadlullah: Work on model and demo<br>
#    Joshua: Help with demo setup <br>
#    Mena: Collect data and begin writing results<br>
#    Mohamed: Train the model<br>

# %% [markdown]
# $Apr. 19$

# %% [markdown]
# | Deliverable  | Percent Complete    | Estimated Completion  Date  | Percent Completed by Next Milestone|
# |:-------------|:-----------|:------|:------|
# | Code | 80%  | Apr. 26      | 100%   |
# | Paper | 75%  | Apr. 21   | 100%   |
# | Demo | 50%  | Apr. 23   | 100%   |
# | Presentation | 10%  |  Apr. 25   | 100%   |

# %% [markdown]
# 1\. We have completed the model, the training, and got results from the model with good accuracy. We have made good  progress on the paper with the methods and the results sections.

# %% [markdown]
# 2\. The code on the arduino is yet to be complete.

# %% [markdown]
# 3\. Before the next milestone, we would like to finalize everything. We need to complete the code for the arduino, the paper, demo, and presentation. The product should be finalized.
#
#    Team Member Roles: <br>
#    Austin: Work on finalizing the paper<br>
#    Fadlullah: Finish arduino code and demo<br>
#    Joshua: Push necessary updates to Github <br>
#    Mena: Work on the presentation<br>
#    Mohamed: Work on putting the paper in the template<br>
